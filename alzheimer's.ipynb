# %%
import os
import cv2 
import itertools
import numpy as np 
import pandas as pd 

test_dir = "C:\\Users\\Srinivas\\OneDrive\\Documents\\Alzheimer_s Dataset\\test"
train_dir = r"C:\Users\Srinivas\OneDrive\Documents\Alzheimer_s Dataset\train"

data = []

# %%
for dirtrain in os.listdir(train_dir): 
    print(dirtrain)
    for tr in os.listdir(os.path.join(train_dir, dirtrain)):  # Use os.path.join to construct the full path
        img = cv2.imread(os.path.join(train_dir, dirtrain, tr))  # Use os.path.join to construct the full image path
        img = cv2.resize(img, (32, 32))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        img = img.reshape(32, 32, 1)
        
        data.append([img, dirtrain])
# Out:
# MildDemented
# ModerateDemented
# NonDemented
# VeryMildDemented

# %%
for dirtest in os.listdir(test_dir):    
    print(dirtest)
    for ts in os.listdir(os.path.join(test_dir, dirtest)):  # Use os.path.join to construct the full path
        img = cv2.imread(os.path.join(test_dir, dirtest, ts))  # Use os.path.join to construct the full image path
        img = cv2.resize(img, (32, 32))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        img = img.reshape(32, 32, 1)
        
        data.append([img, dirtest])
# Out:
# MildDemented
# ModerateDemented
# NonDemented
# VeryMildDemented

# %%
import random
random.seed(20)

# %%
random.shuffle(data)

# %%
x, y = [], []
for e in data:
    x.append(e[0])
    y.append(e[1])

# %%
from sklearn.preprocessing import OneHotEncoder

x = np.array(x)
y = np.array(y)
y = y.reshape(y.shape[0],1)
enc = OneHotEncoder(handle_unknown='ignore').fit(y)
print(enc.categories_)
y = enc.transform(y).toarray()
print(f'Data   :   {str(x.shape)}')
print(f'Labels :   {str(y.shape)}')
# Out:
# [array(['MildDemented', 'ModerateDemented', 'NonDemented',
#        'VeryMildDemented'], dtype='<U16')]
# Data   :   (3959, 32, 32, 1)
# Labels :   (3959, 4)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=1, test_size=0.2)

# %%
import tensorflow as tf

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)
print(tf.config.list_physical_devices('GPU'))
# Out:
# []

# %%
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Conv2D,MaxPooling2D,Flatten,Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator


from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Conv2D,MaxPooling2D,Flatten,Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator


model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(64, (4, 4), padding='same', activation=tf.nn.relu, 
    input_shape=(32, 32, 1)),
    tf.keras.layers.MaxPooling2D((2, 2), strides=(2,2)), Dropout(0.25),
    
    tf.keras.layers.Conv2D(128, (3,3), padding='same', activation=tf.nn.relu),
    tf.keras.layers.MaxPooling2D((2, 2), strides=(2,2)),
    Dropout(0.25),

    tf.keras.layers.Conv2D(128, (3,3), padding='same', activation=tf.nn.relu),
    tf.keras.layers.MaxPooling2D((2, 2), strides=(2,2)),
    Dropout(0.3),

    tf.keras.layers.Conv2D(128, (2,2), padding='same', activation=tf.nn.relu),
    tf.keras.layers.MaxPooling2D((2, 2), strides=(2,2)),
    Dropout(0.3),

    tf.keras.layers.Conv2D(256, (2,2), padding='same', activation=tf.nn.relu),
    tf.keras.layers.MaxPooling2D((2, 2), strides=(2,2)),
    Dropout(0.3),
                    
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(4,  activation=tf.nn.softmax)
])
# Out:
# c:\Users\Srinivas\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 64)     │         1,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 4, 4, 128)      │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 2, 2, 256)      │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 1, 1, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 1, 1, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 452,932 (1.73 MB)
#  Trainable params: 452,932 (1.73 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
tf.keras.utils.plot_model(
    model,
    to_file="model.png",
    show_shapes=True,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=True,
    dpi=96,
)

# %%
model.compile(optimizer='Adam',loss='categorical_crossentropy',metrics=['accuracy'])
hist = model.fit(x_train, y_train, epochs=200, validation_split=0.2, batch_size=64,verbose=1,shuffle=True)
# Out:
# Epoch 1/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 6s 84ms/step - accuracy: 0.5155 - loss: 8.6878 - val_accuracy: 0.6703 - val_loss: 1.1046
# Epoch 2/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step - accuracy: 0.6728 - loss: 0.9140 - val_accuracy: 0.6703 - val_loss: 1.0672
# Epoch 3/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - accuracy: 0.6676 - loss: 0.9178 - val_accuracy: 0.6703 - val_loss: 0.8817
# Epoch 4/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.6634 - loss: 0.8611 - val_accuracy: 0.6703 - val_loss: 0.7897
# Epoch 5/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - accuracy: 0.6813 - loss: 0.7755 - val_accuracy: 0.6703 - val_loss: 0.7635
# Epoch 6/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.6721 - loss: 0.8149 - val_accuracy: 0.6703 - val_loss: 0.8517
# Epoch 7/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - accuracy: 0.6770 - loss: 0.7817 - val_accuracy: 0.6688 - val_loss: 0.7862
# Epoch 8/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.6697 - loss: 0.7664 - val_accuracy: 0.6735 - val_loss: 0.7566
# Epoch 9/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.6747 - loss: 0.7495 - val_accuracy: 0.6719 - val_loss: 0.7396
# Epoch 10/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.6689 - loss: 0.7804 - val_accuracy: 0.6656 - val_loss: 0.8330
# Epoch 11/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.6681 - loss: 0.7857 - val_accuracy: 0.6688 - val_loss: 0.8752
# Epoch 12/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6718 - loss: 0.7736 - val_accuracy: 0.6861 - val_loss: 0.7764
# Epoch 13/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6774 - loss: 0.7581 - val_accuracy: 0.6467 - val_loss: 0.7904
# Epoch 14/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6745 - loss: 0.7199 - val_accuracy: 0.6656 - val_loss: 0.8572
# Epoch 15/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.6856 - loss: 0.7248 - val_accuracy: 0.6609 - val_loss: 0.7719
# Epoch 16/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.6854 - loss: 0.7148 - val_accuracy: 0.6767 - val_loss: 0.7293
# Epoch 17/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6702 - loss: 0.7362 - val_accuracy: 0.6735 - val_loss: 0.6982
# Epoch 18/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6815 - loss: 0.7333 - val_accuracy: 0.7003 - val_loss: 0.7346
# Epoch 19/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.6818 - loss: 0.7019 - val_accuracy: 0.7224 - val_loss: 0.6677
# Epoch 20/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.6804 - loss: 0.7046 - val_accuracy: 0.6972 - val_loss: 0.7798
# Epoch 21/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.6987 - loss: 0.6877 - val_accuracy: 0.7066 - val_loss: 0.7095
# Epoch 22/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.7037 - loss: 0.6789 - val_accuracy: 0.7240 - val_loss: 0.6323
# Epoch 23/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.7143 - loss: 0.6360 - val_accuracy: 0.7571 - val_loss: 0.6042
# Epoch 24/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.6969 - loss: 0.6592 - val_accuracy: 0.7792 - val_loss: 0.6180
# Epoch 25/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.7129 - loss: 0.6563 - val_accuracy: 0.7524 - val_loss: 0.6138
# Epoch 26/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.7108 - loss: 0.6306 - val_accuracy: 0.7256 - val_loss: 0.6493
# Epoch 27/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.7335 - loss: 0.6134 - val_accuracy: 0.7808 - val_loss: 0.5825
# Epoch 28/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.7360 - loss: 0.6061 - val_accuracy: 0.7808 - val_loss: 0.5537
# Epoch 29/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.7501 - loss: 0.5750 - val_accuracy: 0.7587 - val_loss: 0.6253
# Epoch 30/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.7269 - loss: 0.6199 - val_accuracy: 0.7965 - val_loss: 0.5232
# Epoch 31/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.7405 - loss: 0.6171 - val_accuracy: 0.8028 - val_loss: 0.5211
# Epoch 32/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.7432 - loss: 0.5947 - val_accuracy: 0.7776 - val_loss: 0.6489
# Epoch 33/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.7638 - loss: 0.5636 - val_accuracy: 0.7571 - val_loss: 0.5589
# Epoch 34/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.7658 - loss: 0.5436 - val_accuracy: 0.7997 - val_loss: 0.5088
# Epoch 35/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.7793 - loss: 0.5314 - val_accuracy: 0.6893 - val_loss: 0.7222
# Epoch 36/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.7507 - loss: 0.5997 - val_accuracy: 0.8123 - val_loss: 0.4721
# Epoch 37/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.8032 - loss: 0.5034 - val_accuracy: 0.7603 - val_loss: 0.5464
# Epoch 38/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.7857 - loss: 0.5199 - val_accuracy: 0.8076 - val_loss: 0.4634
# Epoch 39/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.7798 - loss: 0.5266 - val_accuracy: 0.7997 - val_loss: 0.4968
# Epoch 40/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.8044 - loss: 0.4710 - val_accuracy: 0.7855 - val_loss: 0.5331
# Epoch 41/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.8070 - loss: 0.4687 - val_accuracy: 0.8328 - val_loss: 0.4238
# Epoch 42/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.8077 - loss: 0.4655 - val_accuracy: 0.8375 - val_loss: 0.4161
# Epoch 43/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.8206 - loss: 0.4574 - val_accuracy: 0.8470 - val_loss: 0.4060
# Epoch 44/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.8262 - loss: 0.4298 - val_accuracy: 0.8091 - val_loss: 0.4522
# Epoch 45/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8343 - loss: 0.4110 - val_accuracy: 0.8675 - val_loss: 0.3856
# Epoch 46/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.8351 - loss: 0.3946 - val_accuracy: 0.8423 - val_loss: 0.4073
# Epoch 47/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.8287 - loss: 0.4196 - val_accuracy: 0.8502 - val_loss: 0.3697
# Epoch 48/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.8318 - loss: 0.4334 - val_accuracy: 0.8675 - val_loss: 0.3658
# Epoch 49/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.8448 - loss: 0.3888 - val_accuracy: 0.8628 - val_loss: 0.3587
# Epoch 50/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.8470 - loss: 0.3938 - val_accuracy: 0.8423 - val_loss: 0.4157
# Epoch 51/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.8552 - loss: 0.3913 - val_accuracy: 0.8470 - val_loss: 0.3738
# Epoch 52/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8537 - loss: 0.3608 - val_accuracy: 0.8675 - val_loss: 0.3370
# Epoch 53/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8519 - loss: 0.3641 - val_accuracy: 0.8218 - val_loss: 0.4518
# Epoch 54/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.8714 - loss: 0.3362 - val_accuracy: 0.8722 - val_loss: 0.3634
# Epoch 55/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8837 - loss: 0.3390 - val_accuracy: 0.8612 - val_loss: 0.3565
# Epoch 56/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.8482 - loss: 0.3700 - val_accuracy: 0.8754 - val_loss: 0.3437
# Epoch 57/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.8832 - loss: 0.2960 - val_accuracy: 0.8644 - val_loss: 0.3360
# Epoch 58/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.8764 - loss: 0.3061 - val_accuracy: 0.8722 - val_loss: 0.3295
# Epoch 59/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8706 - loss: 0.3221 - val_accuracy: 0.8927 - val_loss: 0.2900
# Epoch 60/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.8758 - loss: 0.3120 - val_accuracy: 0.8927 - val_loss: 0.2844
# Epoch 61/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8889 - loss: 0.2801 - val_accuracy: 0.8912 - val_loss: 0.2714
# Epoch 62/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9072 - loss: 0.2496 - val_accuracy: 0.8407 - val_loss: 0.3826
# Epoch 63/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.8718 - loss: 0.3330 - val_accuracy: 0.9006 - val_loss: 0.2804
# Epoch 64/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.8906 - loss: 0.2695 - val_accuracy: 0.8896 - val_loss: 0.2699
# Epoch 65/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9040 - loss: 0.2540 - val_accuracy: 0.8738 - val_loss: 0.3415
# Epoch 66/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9023 - loss: 0.2510 - val_accuracy: 0.8864 - val_loss: 0.2895
# Epoch 67/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9110 - loss: 0.2435 - val_accuracy: 0.8880 - val_loss: 0.2855
# Epoch 68/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8947 - loss: 0.2701 - val_accuracy: 0.8943 - val_loss: 0.2690
# Epoch 69/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9109 - loss: 0.2501 - val_accuracy: 0.9085 - val_loss: 0.2374
# Epoch 70/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9222 - loss: 0.2141 - val_accuracy: 0.8344 - val_loss: 0.3812
# Epoch 71/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.9039 - loss: 0.2633 - val_accuracy: 0.9069 - val_loss: 0.2538
# Epoch 72/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9087 - loss: 0.2418 - val_accuracy: 0.9101 - val_loss: 0.2482
# Epoch 73/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9183 - loss: 0.2269 - val_accuracy: 0.8943 - val_loss: 0.2654
# Epoch 74/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9166 - loss: 0.2107 - val_accuracy: 0.9117 - val_loss: 0.2240
# Epoch 75/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9159 - loss: 0.2230 - val_accuracy: 0.9211 - val_loss: 0.2225
# Epoch 76/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9315 - loss: 0.1973 - val_accuracy: 0.9022 - val_loss: 0.2599
# Epoch 77/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9347 - loss: 0.1777 - val_accuracy: 0.9196 - val_loss: 0.2201
# Epoch 78/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9297 - loss: 0.1957 - val_accuracy: 0.9196 - val_loss: 0.2030
# Epoch 79/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9241 - loss: 0.2092 - val_accuracy: 0.9322 - val_loss: 0.1936
# Epoch 80/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9390 - loss: 0.1767 - val_accuracy: 0.9338 - val_loss: 0.2213
# Epoch 81/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9521 - loss: 0.1382 - val_accuracy: 0.9022 - val_loss: 0.2381
# Epoch 82/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9236 - loss: 0.2149 - val_accuracy: 0.9164 - val_loss: 0.1981
# Epoch 83/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9294 - loss: 0.1774 - val_accuracy: 0.9227 - val_loss: 0.1877
# Epoch 84/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9381 - loss: 0.1645 - val_accuracy: 0.9401 - val_loss: 0.1812
# Epoch 85/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9409 - loss: 0.1556 - val_accuracy: 0.9322 - val_loss: 0.1923
# Epoch 86/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9544 - loss: 0.1415 - val_accuracy: 0.9196 - val_loss: 0.2101
# Epoch 87/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9338 - loss: 0.1877 - val_accuracy: 0.9274 - val_loss: 0.2003
# Epoch 88/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9504 - loss: 0.1549 - val_accuracy: 0.9338 - val_loss: 0.1905
# Epoch 89/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9457 - loss: 0.1613 - val_accuracy: 0.9196 - val_loss: 0.2187
# Epoch 90/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9448 - loss: 0.1727 - val_accuracy: 0.9164 - val_loss: 0.2167
# Epoch 91/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9341 - loss: 0.2050 - val_accuracy: 0.9353 - val_loss: 0.1874
# Epoch 92/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9473 - loss: 0.1335 - val_accuracy: 0.9353 - val_loss: 0.1924
# Epoch 93/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.9506 - loss: 0.1384 - val_accuracy: 0.9243 - val_loss: 0.2420
# Epoch 94/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9419 - loss: 0.1702 - val_accuracy: 0.9227 - val_loss: 0.2063
# Epoch 95/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9431 - loss: 0.1579 - val_accuracy: 0.9353 - val_loss: 0.1780
# Epoch 96/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9386 - loss: 0.1760 - val_accuracy: 0.9274 - val_loss: 0.1976
# Epoch 97/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9535 - loss: 0.1496 - val_accuracy: 0.9274 - val_loss: 0.1935
# Epoch 98/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9548 - loss: 0.1207 - val_accuracy: 0.9401 - val_loss: 0.1865
# Epoch 99/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9513 - loss: 0.1376 - val_accuracy: 0.9274 - val_loss: 0.1834
# Epoch 100/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9621 - loss: 0.0996 - val_accuracy: 0.9353 - val_loss: 0.1809
# Epoch 101/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9550 - loss: 0.1314 - val_accuracy: 0.9495 - val_loss: 0.1591
# Epoch 102/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9696 - loss: 0.0971 - val_accuracy: 0.9306 - val_loss: 0.1715
# Epoch 103/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9590 - loss: 0.1150 - val_accuracy: 0.9338 - val_loss: 0.1823
# Epoch 104/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9612 - loss: 0.1155 - val_accuracy: 0.9401 - val_loss: 0.1903
# Epoch 105/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9523 - loss: 0.1256 - val_accuracy: 0.9385 - val_loss: 0.1986
# Epoch 106/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9585 - loss: 0.1163 - val_accuracy: 0.9148 - val_loss: 0.2488
# Epoch 107/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.9532 - loss: 0.1262 - val_accuracy: 0.9416 - val_loss: 0.1874
# Epoch 108/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9650 - loss: 0.1009 - val_accuracy: 0.9432 - val_loss: 0.1698
# Epoch 109/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9636 - loss: 0.1093 - val_accuracy: 0.9290 - val_loss: 0.2170
# Epoch 110/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9659 - loss: 0.0992 - val_accuracy: 0.9243 - val_loss: 0.2148
# Epoch 111/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9644 - loss: 0.1078 - val_accuracy: 0.9401 - val_loss: 0.1849
# Epoch 112/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9695 - loss: 0.0909 - val_accuracy: 0.9322 - val_loss: 0.1815
# Epoch 113/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9580 - loss: 0.1325 - val_accuracy: 0.9416 - val_loss: 0.1622
# Epoch 114/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9728 - loss: 0.0893 - val_accuracy: 0.9243 - val_loss: 0.2225
# Epoch 115/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9607 - loss: 0.1143 - val_accuracy: 0.9464 - val_loss: 0.1734
# Epoch 116/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9770 - loss: 0.0757 - val_accuracy: 0.9290 - val_loss: 0.2137
# Epoch 117/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9708 - loss: 0.0945 - val_accuracy: 0.9448 - val_loss: 0.1656
# Epoch 118/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9634 - loss: 0.1056 - val_accuracy: 0.9495 - val_loss: 0.1810
# Epoch 119/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9664 - loss: 0.1103 - val_accuracy: 0.9306 - val_loss: 0.1955
# Epoch 120/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9525 - loss: 0.1267 - val_accuracy: 0.9369 - val_loss: 0.1893
# Epoch 121/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9727 - loss: 0.0782 - val_accuracy: 0.9416 - val_loss: 0.1727
# Epoch 122/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9634 - loss: 0.1058 - val_accuracy: 0.9290 - val_loss: 0.1971
# Epoch 123/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9621 - loss: 0.1080 - val_accuracy: 0.9432 - val_loss: 0.1663
# Epoch 124/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9674 - loss: 0.0968 - val_accuracy: 0.9464 - val_loss: 0.1554
# Epoch 125/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9676 - loss: 0.0883 - val_accuracy: 0.9527 - val_loss: 0.1561
# Epoch 126/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9739 - loss: 0.0806 - val_accuracy: 0.9401 - val_loss: 0.1854
# Epoch 127/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9660 - loss: 0.1000 - val_accuracy: 0.9432 - val_loss: 0.1755
# Epoch 128/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9608 - loss: 0.1114 - val_accuracy: 0.9495 - val_loss: 0.1521
# Epoch 129/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9771 - loss: 0.0704 - val_accuracy: 0.9432 - val_loss: 0.1653
# Epoch 130/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9728 - loss: 0.0817 - val_accuracy: 0.9322 - val_loss: 0.1931
# Epoch 131/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9574 - loss: 0.0987 - val_accuracy: 0.9432 - val_loss: 0.1639
# Epoch 132/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9689 - loss: 0.0966 - val_accuracy: 0.9401 - val_loss: 0.1618
# Epoch 133/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9713 - loss: 0.0867 - val_accuracy: 0.9416 - val_loss: 0.1745
# Epoch 134/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9719 - loss: 0.0660 - val_accuracy: 0.9369 - val_loss: 0.1991
# Epoch 135/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9688 - loss: 0.1005 - val_accuracy: 0.9227 - val_loss: 0.2175
# Epoch 136/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9651 - loss: 0.0903 - val_accuracy: 0.9290 - val_loss: 0.1844
# Epoch 137/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9734 - loss: 0.0748 - val_accuracy: 0.9401 - val_loss: 0.1634
# Epoch 138/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9676 - loss: 0.0803 - val_accuracy: 0.9558 - val_loss: 0.1416
# Epoch 139/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9836 - loss: 0.0499 - val_accuracy: 0.9369 - val_loss: 0.1520
# Epoch 140/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9812 - loss: 0.0562 - val_accuracy: 0.9464 - val_loss: 0.1495
# Epoch 141/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9658 - loss: 0.0908 - val_accuracy: 0.9401 - val_loss: 0.1910
# Epoch 142/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9772 - loss: 0.0684 - val_accuracy: 0.9353 - val_loss: 0.1936
# Epoch 143/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9781 - loss: 0.0611 - val_accuracy: 0.9416 - val_loss: 0.1609
# Epoch 144/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9755 - loss: 0.0844 - val_accuracy: 0.9464 - val_loss: 0.1416
# Epoch 145/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9667 - loss: 0.1026 - val_accuracy: 0.9369 - val_loss: 0.1545
# Epoch 146/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9744 - loss: 0.0844 - val_accuracy: 0.9448 - val_loss: 0.1621
# Epoch 147/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9734 - loss: 0.0730 - val_accuracy: 0.9432 - val_loss: 0.1609
# Epoch 148/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9782 - loss: 0.0687 - val_accuracy: 0.9574 - val_loss: 0.1504
# Epoch 149/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9811 - loss: 0.0522 - val_accuracy: 0.9558 - val_loss: 0.1374
# Epoch 150/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9764 - loss: 0.0706 - val_accuracy: 0.9416 - val_loss: 0.1592
# Epoch 151/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9791 - loss: 0.0694 - val_accuracy: 0.9495 - val_loss: 0.1564
# Epoch 152/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9744 - loss: 0.0833 - val_accuracy: 0.9527 - val_loss: 0.1570
# Epoch 153/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9720 - loss: 0.0750 - val_accuracy: 0.9338 - val_loss: 0.1946
# Epoch 154/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9759 - loss: 0.0764 - val_accuracy: 0.9543 - val_loss: 0.1257
# Epoch 155/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9756 - loss: 0.0621 - val_accuracy: 0.9495 - val_loss: 0.1559
# Epoch 156/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9720 - loss: 0.0761 - val_accuracy: 0.9464 - val_loss: 0.1552
# Epoch 157/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9670 - loss: 0.0948 - val_accuracy: 0.9416 - val_loss: 0.1877
# Epoch 158/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9717 - loss: 0.0922 - val_accuracy: 0.9511 - val_loss: 0.1612
# Epoch 159/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9687 - loss: 0.0851 - val_accuracy: 0.9416 - val_loss: 0.1817
# Epoch 160/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9786 - loss: 0.0624 - val_accuracy: 0.9558 - val_loss: 0.1654
# Epoch 161/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9799 - loss: 0.0577 - val_accuracy: 0.9401 - val_loss: 0.1601
# Epoch 162/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9734 - loss: 0.1125 - val_accuracy: 0.9495 - val_loss: 0.1648
# Epoch 163/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9780 - loss: 0.0744 - val_accuracy: 0.9401 - val_loss: 0.1747
# Epoch 164/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9777 - loss: 0.0486 - val_accuracy: 0.9511 - val_loss: 0.1448
# Epoch 165/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9897 - loss: 0.0364 - val_accuracy: 0.9558 - val_loss: 0.1706
# Epoch 166/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9763 - loss: 0.0750 - val_accuracy: 0.9464 - val_loss: 0.1877
# Epoch 167/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9714 - loss: 0.0980 - val_accuracy: 0.9448 - val_loss: 0.1701
# Epoch 168/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9774 - loss: 0.0537 - val_accuracy: 0.9448 - val_loss: 0.1562
# Epoch 169/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9750 - loss: 0.0778 - val_accuracy: 0.9543 - val_loss: 0.1539
# Epoch 170/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9789 - loss: 0.0642 - val_accuracy: 0.9511 - val_loss: 0.1579
# Epoch 171/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9751 - loss: 0.0664 - val_accuracy: 0.9590 - val_loss: 0.1274
# Epoch 172/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9838 - loss: 0.0467 - val_accuracy: 0.9401 - val_loss: 0.1681
# Epoch 173/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9782 - loss: 0.0578 - val_accuracy: 0.9495 - val_loss: 0.1734
# Epoch 174/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9745 - loss: 0.0841 - val_accuracy: 0.9416 - val_loss: 0.1674
# Epoch 175/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9804 - loss: 0.0628 - val_accuracy: 0.9479 - val_loss: 0.1415
# Epoch 176/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9880 - loss: 0.0453 - val_accuracy: 0.9574 - val_loss: 0.1795
# Epoch 177/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9781 - loss: 0.0800 - val_accuracy: 0.9511 - val_loss: 0.1420
# Epoch 178/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9744 - loss: 0.0750 - val_accuracy: 0.9511 - val_loss: 0.1627
# Epoch 179/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9829 - loss: 0.0488 - val_accuracy: 0.9511 - val_loss: 0.1445
# Epoch 180/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9776 - loss: 0.0690 - val_accuracy: 0.9590 - val_loss: 0.1664
# Epoch 181/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9815 - loss: 0.0534 - val_accuracy: 0.9543 - val_loss: 0.1724
# Epoch 182/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9793 - loss: 0.0650 - val_accuracy: 0.9416 - val_loss: 0.1895
# Epoch 183/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9653 - loss: 0.0915 - val_accuracy: 0.9464 - val_loss: 0.1585
# Epoch 184/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9798 - loss: 0.0576 - val_accuracy: 0.9495 - val_loss: 0.1603
# Epoch 185/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9880 - loss: 0.0474 - val_accuracy: 0.9558 - val_loss: 0.1612
# Epoch 186/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9852 - loss: 0.0384 - val_accuracy: 0.9464 - val_loss: 0.1811
# Epoch 187/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9803 - loss: 0.0643 - val_accuracy: 0.9527 - val_loss: 0.1871
# Epoch 188/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9854 - loss: 0.0460 - val_accuracy: 0.9574 - val_loss: 0.1689
# Epoch 189/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9773 - loss: 0.0513 - val_accuracy: 0.9401 - val_loss: 0.1840
# Epoch 190/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9765 - loss: 0.0715 - val_accuracy: 0.9574 - val_loss: 0.1507
# Epoch 191/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9843 - loss: 0.0437 - val_accuracy: 0.9574 - val_loss: 0.2184
# Epoch 192/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9732 - loss: 0.0870 - val_accuracy: 0.9495 - val_loss: 0.1625
# Epoch 193/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9833 - loss: 0.0524 - val_accuracy: 0.9527 - val_loss: 0.1905
# Epoch 194/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9772 - loss: 0.0731 - val_accuracy: 0.9543 - val_loss: 0.1744
# Epoch 195/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9776 - loss: 0.0647 - val_accuracy: 0.9385 - val_loss: 0.1725
# Epoch 196/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9822 - loss: 0.0535 - val_accuracy: 0.9527 - val_loss: 0.1973
# Epoch 197/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9808 - loss: 0.0504 - val_accuracy: 0.9401 - val_loss: 0.2520
# Epoch 198/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9827 - loss: 0.0541 - val_accuracy: 0.9495 - val_loss: 0.1655
# Epoch 199/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9812 - loss: 0.0669 - val_accuracy: 0.9448 - val_loss: 0.1798
# Epoch 200/200
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9926 - loss: 0.0291 - val_accuracy: 0.9527 - val_loss: 0.1871

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

fig = plt.figure(figsize=(12, 6), dpi=80)
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure(figsize=(12, 6), dpi=80)
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
loss_and_metrics = model.evaluate(x_test, y_test, verbose=2)
y_pred = model.predict(x_test).argmax(axis=1)
print(f'Test Loss     : {loss_and_metrics[0]}')
print(f'Test Accuracy : {loss_and_metrics[1]}')
print(y_test.shape, y_pred.shape)
# Out:
# 25/25 - 0s - 10ms/step - accuracy: 0.9482 - loss: 0.2426
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Test Loss     : 0.24256636202335358
# Test Accuracy : 0.9482323527336121
# (792, 4) (792,)

# %%
from sklearn import metrics

df = pd.DataFrame(
  data = metrics.confusion_matrix(np.argmax(y_test, axis=1), y_pred),
  columns = ['0', '1', '2', '3'],
  index = ['0', '1', '2', '3']
)
df
# Out:
#     0   1    2    3
# 0  69   0    3    7
# 1   1  11    0    0
# 2   2   0  533    4
# 3   1   0   23  138

# %%
import seaborn as sns

sns.heatmap(df, cmap="Reds", annot=True, fmt='.0f')
# Out:
# <AxesSubplot:>

# %%
model.save('mdl.keras')

# %%
model.save('model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
